# %%
from apify_client import ApifyClient

# Initialize the ApifyClient with your API token
client = ApifyClient("API-KEY")

# Prepare the Actor input
run_input = {
    "commentsPerPost": 1000,
    "excludePinnedPosts": False,
    "maxRepliesPerComment": 0,
    "postURLs": [
        "https://vt.tiktok.com/ZSDETKDro/"
    ],
    "resultsPerPage": 100
}

# Run the Actor and wait for it to finish
run = client.actor("BDec00yAmCm1QbMEI").call(run_input=run_input)

items = list(client.dataset(run["defaultDatasetId"]).iterate_items())
# Out:
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message:
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:51:05.410Z ACTOR: Pulling Docker image of build EisyP6FKLpdtuhOcD from registry.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:51:05.412Z ACTOR: Creating Docker container.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:51:06.034Z ACTOR: Starting Docker container.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:51:06.255Z Will run command: xvfb-run -a -s "-ac -screen 0 1920x1080x24+32 -nolisten tcp" /bin/sh -c ./start_xvfb_and_run_cmd.sh && npm run start:prod --silent
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:51:07.498Z INFO  System info {"apifyVersion":"3.4.2","apifyClientVersion":"2.12.6","crawleeVersion":"3.13.9","osType":"Linux","nodeVersion":"v20.19.5"}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Starting the crawler.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:51:08.390Z INFO  CheerioCrawler: Starting the crawler.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 0/1 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:51:18.251Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 0.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Scraped 0/1 posts for top-level comments. Total comments scraped: 0.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 0/1 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:51:28.250Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 0.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:51:38.250Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 0.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:51:48.250Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 0.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:51:58.251Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 0.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:08.252Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 0.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:08.391Z INFO  CheerioCrawler:Statistics: CheerioCrawler request statistics: {"requestAvgFailedDurationMillis":null,"requestAvgFinishedDurationMillis":null,"requestsFinishedPerMinute":0,"requestsFailedPerMinute":0,"requestTotalDurationMillis":0,"requestsTotal":0,"crawlerRuntimeMillis":60215,"retryHistogram":[]}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:08.411Z INFO  CheerioCrawler:AutoscaledPool: state {"currentConcurrency":1,"desiredConcurrency":10,"systemStatus":{"isSystemIdle":true,"memInfo":{"isOverloaded":false,"limitRatio":0.2,"actualRatio":0},"eventLoopInfo":{"isOverloaded":false,"limitRatio":0.7,"actualRatio":0},"cpuInfo":{"isOverloaded":false,"limitRatio":0.4,"actualRatio":0},"clientInfo":{"isOverloaded":false,"limitRatio":0.3,"actualRatio":0}}}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:09.418Z INFO  [POST] Starting the post scrape.  --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:09.419Z INFO  [POST] Starting the comments scrape.  --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:09.475Z INFO  [POST] Post scraped successfully.  --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 1/6 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:18.253Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 0.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:23.883Z INFO  Scraped 28 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 2/7 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:28.253Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 28.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:32.465Z INFO  Scraped 16 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:34.268Z INFO  Scraped 1 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:36.417Z INFO  Scraped 21 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 5/10 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:38.254Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 66.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:46.695Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Failed to parse TikTok response: Unexpected end of JSON input --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:46.696Z     at makeWebApiCall (file:///home/myuser/dist/src/tools/api/web/make-web-api-call.js:108:54) {"id":"gP4Rx9P4pViXQnm","url":"https://vt.tiktok.com/ZSDETKDro/","retryCount":1}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:48.253Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 66.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:49.841Z INFO  Scraped 10 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:51.747Z INFO  Scraped 3 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 7/12 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:52:58.254Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 79.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:05.282Z INFO  Scraped 9 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:08.253Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 88.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:08.390Z INFO  CheerioCrawler:Statistics: CheerioCrawler request statistics: {"requestAvgFailedDurationMillis":null,"requestAvgFinishedDurationMillis":24031,"requestsFinishedPerMinute":4,"requestsFailedPerMinute":0,"requestTotalDurationMillis":216281,"requestsTotal":9,"crawlerRuntimeMillis":120214,"retryHistogram":[8,1]}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:08.413Z INFO  CheerioCrawler:AutoscaledPool: state {"currentConcurrency":5,"desiredConcurrency":10,"systemStatus":{"isSystemIdle":true,"memInfo":{"isOverloaded":false,"limitRatio":0.2,"actualRatio":0},"eventLoopInfo":{"isOverloaded":false,"limitRatio":0.7,"actualRatio":0},"cpuInfo":{"isOverloaded":false,"limitRatio":0.4,"actualRatio":0},"clientInfo":{"isOverloaded":false,"limitRatio":0.3,"actualRatio":0}}}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:09.047Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request timed out after 30 seconds
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 9/14 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:09.047Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:25:73) {"id":"ZY8dO7LEELLoFKC","url":"https://vt.tiktok.com/ZSDETKDro/","retryCount":1}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Scraped 0/1 posts for top-level comments. Total comments scraped: 88.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 10/15 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:18.253Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 88.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:28.255Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 88.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:29.144Z INFO  Scraped 30 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:34.414Z INFO  Scraped 23 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 13/18 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:38.254Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 141.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:42.923Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Failed to parse TikTok response: Unexpected end of JSON input --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:42.924Z     at makeWebApiCall (file:///home/myuser/dist/src/tools/api/web/make-web-api-call.js:108:54) {"id":"YjHQ8HurH7kQ6Mh","url":"https://vt.tiktok.com/ZSDETKDro/","retryCount":1}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:45.697Z INFO  Scraped 16 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 14/19 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:48.253Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 157.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:54.164Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request timed out after 30 seconds
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:54.165Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:25:73) {"id":"ZY8dO7LEELLoFKC","url":"https://vt.tiktok.com/ZSDETKDro/","retryCount":2}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:53:58.254Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 157.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:08.253Z INFO  Scraped 8 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:08.254Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 165.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:08.390Z INFO  CheerioCrawler:Statistics: CheerioCrawler request statistics: {"requestAvgFailedDurationMillis":null,"requestAvgFinishedDurationMillis":22644,"requestsFinishedPerMinute":6,"requestsFailedPerMinute":0,"requestTotalDurationMillis":384943,"requestsTotal":17,"crawlerRuntimeMillis":180214,"retryHistogram":[15,2]}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 17/22 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:08.417Z INFO  CheerioCrawler:AutoscaledPool: state {"currentConcurrency":5,"desiredConcurrency":10,"systemStatus":{"isSystemIdle":true,"memInfo":{"isOverloaded":false,"limitRatio":0.2,"actualRatio":0},"eventLoopInfo":{"isOverloaded":false,"limitRatio":0.7,"actualRatio":0},"cpuInfo":{"isOverloaded":false,"limitRatio":0.4,"actualRatio":0},"clientInfo":{"isOverloaded":false,"limitRatio":0.3,"actualRatio":0}}}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:15.714Z INFO  Scraped 14 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 18/23 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:18.254Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 179.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:19.033Z INFO  Scraped 1 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:19.968Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Failed to send API request with exit code, retrying
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:19.969Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:25:43) {"id":"nMGmxJpLVrNKpIf","url":"https://vt.tiktok.com/ZSDETKDro/","retryCount":1}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:25.130Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Failed to send API request with exit code, retrying
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:25.131Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:25:43) {"id":"gMNTCaHhuMnt0fm","url":"https://vt.tiktok.com/ZSDETKDro/","retryCount":1}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 19/24 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:28.254Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 180.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:34.662Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request timed out after 30 seconds
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:34.664Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:25:73) {"id":"ZY8dO7LEELLoFKC","url":"https://vt.tiktok.com/ZSDETKDro/","retryCount":3}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:38.255Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 180.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 20/25 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:38.814Z ACTOR: Sending 'migrating' event to Actor so that it can prepare for migration to another server. See more info at https://apify.it/migrations.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:39.611Z INFO  Scraped 24 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 22/27 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:48.255Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 204.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:58.256Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 204.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:54:58.815Z ERROR CheerioCrawler: The crawler was paused due to migration to another host, but some requests did not finish in time. Those requests' results may be duplicated.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:05.815Z ACTOR: Sending Docker container SIGTERM signal.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:06.971Z ACTOR: Run was migrated to a new host.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:06.973Z ACTOR: Pulling Docker image of build EisyP6FKLpdtuhOcD from registry.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:06.975Z ACTOR: Creating Docker container.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:07.004Z ACTOR: Starting Docker container.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:07.165Z Will run command: xvfb-run -a -s "-ac -screen 0 1920x1080x24+32 -nolisten tcp" /bin/sh -c ./start_xvfb_and_run_cmd.sh && npm run start:prod --silent
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:10.708Z INFO  System info {"apifyVersion":"3.4.2","apifyClientVersion":"2.12.6","crawleeVersion":"3.13.9","osType":"Linux","nodeVersion":"v20.19.5"}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Starting the crawler.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:11.394Z INFO  CheerioCrawler: Starting the crawler.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 22/28 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:21.244Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 204.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:28.580Z INFO  Scraped 16 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:29.436Z INFO  Scraped 1 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 24/30 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:31.243Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 221.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:38.725Z INFO  Scraped 1 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:38.833Z INFO  Scraped 19 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 26/32 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:41.244Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 241.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:51.037Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request timed out after 30 seconds
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:51.039Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:25:73) {"id":"ZY8dO7LEELLoFKC","url":"https://vt.tiktok.com/ZSDETKDro/","retryCount":4}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 27/33 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:55:51.243Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 241.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 28/34 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:56:01.243Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 241.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:56:03.838Z INFO  Scraped 8 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:56:03.997Z INFO  Scraped 18 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:56:11.243Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 267.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:56:11.394Z INFO  CheerioCrawler:Statistics: CheerioCrawler request statistics: {"requestAvgFailedDurationMillis":null,"requestAvgFinishedDurationMillis":23114,"requestsFinishedPerMinute":6,"requestsFailedPerMinute":0,"requestTotalDurationMillis":716536,"requestsTotal":31,"crawlerRuntimeMillis":290639,"retryHistogram":[27,4]}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 31/37 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:56:11.415Z INFO  CheerioCrawler:AutoscaledPool: state {"currentConcurrency":5,"desiredConcurrency":10,"systemStatus":{"isSystemIdle":true,"memInfo":{"isOverloaded":false,"limitRatio":0.2,"actualRatio":0},"eventLoopInfo":{"isOverloaded":false,"limitRatio":0.7,"actualRatio":0},"cpuInfo":{"isOverloaded":false,"limitRatio":0.4,"actualRatio":0},"clientInfo":{"isOverloaded":false,"limitRatio":0.3,"actualRatio":0}}}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Scraped 0/1 posts for top-level comments. Total comments scraped: 267.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 31/37 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:56:21.243Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 267.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:56:28.977Z INFO  Scraped 17 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 33/39 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:56:31.243Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 284.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:56:33.245Z INFO  Scraped 1 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 34/40 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:56:41.243Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 285.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:56:41.817Z INFO  Scraped 29 new comments. --- https://vt.tiktok.com/ZSDETKDro/
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:56:43.948Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request timed out after 30 seconds
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:56:43.949Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:25:73) {"id":"ZY8dO7LEELLoFKC","url":"https://vt.tiktok.com/ZSDETKDro/","retryCount":5}
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 36/42 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:56:51.244Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 314.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 37/43 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> 2025-10-03T10:57:01.243Z INFO  [Status message]: Scraped 0/1 posts for top-level comments. Total comments scraped: 314.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 40/46 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 43/49 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 44/50 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 47/53 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:Qw323S53zbjbMvfXR] -> Status: RUNNING, Message: Crawled 48/54 pages, 0 failed requests, desired concurrency 10.
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[31], line 18
#       7 run_input = {
#       8     "commentsPerPost": 1000,
#       9     "excludePinnedPosts": False,
#    (...)
#      14     "resultsPerPage": 100
#      15 }
#      17 # Run the Actor and wait for it to finish
# ---> 18 run = client.actor("BDec00yAmCm1QbMEI").call(run_input=run_input)
#      20 items = list(client.dataset(run["defaultDatasetId"]).iterate_items())
#
# File c:\Users\wills\anaconda3\Lib\site-packages\apify_client\_logging.py:86, in _injects_client_details_to_log_context.<locals>.wrapper(resource_client, *args, **kwargs)
#      83 log_context.client_method.set(fun.__qualname__)
#      84 log_context.resource_id.set(resource_client.resource_id)
# ---> 86 return fun(resource_client, *args, **kwargs)
#
# File c:\Users\wills\anaconda3\Lib\site-packages\apify_client\clients\resource_clients\actor.py:355, in ActorClient.call(self, run_input, content_type, build, max_items, max_total_charge_usd, memory_mbytes, timeout_secs, webhooks, force_permission_level, wait_secs, logger)
#     352     logger = None
#     354 with run_client.get_status_message_watcher(to_logger=logger), run_client.get_streamed_log(to_logger=logger):
# --> 355     return self.root_client.run(started_run['id']).wait_for_finish(wait_secs=wait_secs)
#
# File c:\Users\wills\anaconda3\Lib\site-packages\apify_client\_logging.py:86, in _injects_client_details_to_log_context.<locals>.wrapper(resource_client, *args, **kwargs)
#      83 log_context.client_method.set(fun.__qualname__)
#      84 log_context.resource_id.set(resource_client.resource_id)
# ---> 86 return fun(resource_client, *args, **kwargs)
#
# File c:\Users\wills\anaconda3\Lib\site-packages\apify_client\clients\resource_clients\run.py:116, in RunClient.wait_for_finish(self, wait_secs)
#     106 def wait_for_finish(self, *, wait_secs: int | None = None) -> dict | None:
#     107     """Wait synchronously until the run finishes or the server times out.
#     108
#     109     Args:
#    (...)
#     114             TIMED_OUT, ABORTED), then the run has not yet finished.
#     115     """
# --> 116     return self._wait_for_finish(wait_secs=wait_secs)
#
# File c:\Users\wills\anaconda3\Lib\site-packages\apify_client\clients\base\actor_job_base_client.py:41, in ActorJobBaseClient._wait_for_finish(self, wait_secs)
#      35 try:
#      36     response = self.http_client.call(
#      37         url=self._url(),
#      38         method='GET',
#      39         params=self._params(waitForFinish=wait_for_finish),
#      40     )
# ---> 41     job = parse_date_fields(pluck_data(jsonlib.loads(response.text)))
#      43     seconds_elapsed = math.floor((datetime.now(timezone.utc) - started_at).total_seconds())
#      44     if ActorJobStatus(job['status']).is_terminal or (
#      45         wait_secs is not None and seconds_elapsed >= wait_secs
#      46     ):
#
# File c:\Users\wills\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\wills\anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File c:\Users\wills\anaconda3\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import pandas as pd
df = pd.DataFrame(items)
df
# Out:
#                                            videoWebUrl  \
# 0    https://www.tiktok.com/@suaradotcom/video/7543...
# 1    https://www.tiktok.com/@suaradotcom/video/7543...
# 2    https://www.tiktok.com/@suaradotcom/video/7543...
# 3    https://www.tiktok.com/@suaradotcom/video/7543...
# 4    https://www.tiktok.com/@suaradotcom/video/7543...
# ..                                                 ...
# 995  https://www.tiktok.com/@suaradotcom/video/7543...
# 996  https://www.tiktok.com/@suaradotcom/video/7543...
# 997  https://www.tiktok.com/@suaradotcom/video/7543...
# 998  https://www.tiktok.com/@suaradotcom/video/7543...
# 999  https://www.tiktok.com/@suaradotcom/video/7543...
#
#                     submittedVideoUrl                             input  \
# 0    https://vt.tiktok.com/ZSDvBK6vo/  https://vt.tiktok.com/ZSDvBK6vo/
# 1    https://vt.tiktok.com/ZSDvBK6vo/  https://vt.tiktok.com/ZSDvBK6vo/
# 2    https://vt.tiktok.com/ZSDvBK6vo/  https://vt.tiktok.com/ZSDvBK6vo/
# 3    https://vt.tiktok.com/ZSDvBK6vo/  https://vt.tiktok.com/ZSDvBK6vo/
# 4    https://vt.tiktok.com/ZSDvBK6vo/  https://vt.tiktok.com/ZSDvBK6vo/
# ..                                ...                               ...
# 995  https://vt.tiktok.com/ZSDvBK6vo/  https://vt.tiktok.com/ZSDvBK6vo/
# 996  https://vt.tiktok.com/ZSDvBK6vo/  https://vt.tiktok.com/ZSDvBK6vo/
# 997  https://vt.tiktok.com/ZSDvBK6vo/  https://vt.tiktok.com/ZSDvBK6vo/
# 998  https://vt.tiktok.com/ZSDvBK6vo/  https://vt.tiktok.com/ZSDvBK6vo/
# 999  https://vt.tiktok.com/ZSDvBK6vo/  https://vt.tiktok.com/ZSDvBK6vo/
#
#                      cid  createTime             createTimeISO  \
# 0    7543601029847221009  1756381495  2025-08-28T11:44:55.000Z
# 1    7543632648650294034  1756388849  2025-08-28T13:47:29.000Z
# 2    7543576670286332690  1756375821  2025-08-28T10:10:21.000Z
# 3    7543641927926678289  1756391014  2025-08-28T14:23:34.000Z
# 4    7543586532893868818  1756378115  2025-08-28T10:48:35.000Z
# ..                   ...         ...                       ...
# 995  7543668649542861586  1756397230  2025-08-28T16:07:10.000Z
# 996  7543668609840743176  1756397224  2025-08-28T16:07:04.000Z
# 997  7543668538424689424  1756397216  2025-08-28T16:06:56.000Z
# 998  7543661018389070610  1756395456  2025-08-28T15:37:36.000Z
# 999  7543669418569548561  1756397421  2025-08-28T16:10:21.000Z
#
#                                                   text  diggCount  \
# 0     kenapa gak sewa mobil sepitank sih biar imbang 🤣      59067
# 1                                     kalo peke ini🗿🗿🔥      14500
# 2                   PAK PRABOWO CUKUP 1 PERIODE AJA 😭😭      51993
# 3    yg ojol ketabrak mobil brimob knp ga ada yg up...      18123
# 4    jangan pakai petasan...trus gas Airmata dari a...     105763
# ..                                                 ...        ...
# 995                          Waktunya rakyat berkuasaa          0
# 996  @Kendrick:saya mempunyai teman yg ayahnya angg...          0
# 997                             jakarta sedang sakit😁😁          0
# 998  giliran rakyat cuma pakai petasan diberitain,y...          0
# 999  Ini udah demo sampe 2 kali presidennya diem aj...          0
#
#      likedByAuthor  pinnedByAuthor repliesToId  replyCommentTotal  \
# 0            False           False        None                413
# 1            False           False        None                131
# 2            False           False        None                724
# 3            False           False        None                254
# 4            False           False        None                109
# ..             ...             ...         ...                ...
# 995          False           False        None                  0
# 996          False           False        None                  0
# 997          False           False        None                  0
# 998          False           False        None                  0
# 999          False           False        None                  0
#
#                      uid           uniqueId  \
# 0    7245010916981916674          b.prast08
# 1    7454460874980869127          rasmi_568
# 2    7109017569046545435        jakartatime
# 3    7199132755190809627          halfbigel
# 4    7401777070478459910         farne_news
# ..                   ...                ...
# 995  6884226041284871170     walikotauranus
# 996  6973099631099200513  wsoqpqjshzbayudwl
# 997  7410887344934847493          sapril765
# 998  6999275832184374299      urchoiceeeexx
# 999  6666385469289267201        jenengku_di
#
#                                        avatarThumbnail mentions  \
# 0    https://p16-common-sign.tiktokcdn-us.com/tos-a...       []
# 1    https://p16-common-sign.tiktokcdn-us.com/tos-a...       []
# 2    https://p16-common-sign.tiktokcdn-us.com/tos-a...       []
# 3    https://p16-common-sign.tiktokcdn-us.com/tos-a...       []
# 4    https://p16-common-sign.tiktokcdn-us.com/tos-a...       []
# ..                                                 ...      ...
# 995  https://p16-common-sign.tiktokcdn-us.com/tos-m...       []
# 996  https://p16-common-sign.tiktokcdn-us.com/tos-a...       []
# 997  https://p16-common-sign.tiktokcdn-us.com/tos-a...       []
# 998  https://p16-common-sign.tiktokcdn-us.com/tos-m...       []
# 999  https://p19-common-sign.tiktokcdn-us.com/tos-u...       []
#
#     detailedMentions
# 0                 []
# 1                 []
# 2                 []
# 3                 []
# 4                 []
# ..               ...
# 995               []
# 996               []
# 997               []
# 998               []
# 999               []
#
# [1000 rows x 17 columns]

# %%
df.to_excel("scraping_tiktok_10.xlsx", index=False)
